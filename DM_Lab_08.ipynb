# %% [markdown]
# <a href="https://colab.research.google.com/github/Jangala-Megha-Harsha/Data-Mining-2025/blob/main/DM_Lab_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lab-08:**
# **6. Data Transformation**
#
#
#
# *   **1. Perform data encoding (one-hot encoding, label encoding)**
# *   **2. Create new derived columns using existing data (e.g., age from a date of birth)**
# *   **3. Group and aggregate data using groupby and pivot_table**

# %% [markdown]
# ## 1. Performing data encoding

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
# Example Data
data = {'Category': ['A', 'B', 'C', 'A', 'B']}
df = pd.DataFrame(data)

# %%
df
# Out:
#   Category
# 0        A
# 1        B
# 2        C
# 3        A
# 4        B

# %%
df.describe()
# Out:
#        Category
# count         5
# unique        3
# top           A
# freq          2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  5 non-null      object
# dtypes: object(1)
# memory usage: 172.0+ bytes

# %%
# Label Encoding
label_encoder = LabelEncoder()
df['Label_Encoded'] = label_encoder.fit_transform(df['Category'])

# %%
df['Label_Encoded']
# Out:
# 0    0
# 1    1
# 2    2
# 3    0
# 4    1
# Name: Label_Encoded, dtype: int64

# %%
df
# Out:
#   Category  Label_Encoded
# 0        A              0
# 1        B              1
# 2        C              2
# 3        A              0
# 4        B              1

# %%
df.describe()
# Out:
#        Label_Encoded
# count        5.00000
# mean         0.80000
# std          0.83666
# min          0.00000
# 25%          0.00000
# 50%          1.00000
# 75%          1.00000
# max          2.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Category       5 non-null      object
#  1   Label_Encoded  5 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 212.0+ bytes

# %%
# One Hot Encoding
one_hot_encoded = pd.get_dummies(df['Category'], prefix='Category')
df = pd.concat([df, one_hot_encoded], axis=1)

# %%
df
# Out:
#   Category  Label_Encoded  Category_A  Category_B  Category_C
# 0        A              0        True       False       False
# 1        B              1       False        True       False
# 2        C              2       False       False        True
# 3        A              0        True       False       False
# 4        B              1       False        True       False

# %%
df.describe()
# Out:
#        Label_Encoded
# count        5.00000
# mean         0.80000
# std          0.83666
# min          0.00000
# 25%          0.00000
# 50%          1.00000
# 75%          1.00000
# max          2.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Category       5 non-null      object
#  1   Label_Encoded  5 non-null      int64
#  2   Category_A     5 non-null      bool
#  3   Category_B     5 non-null      bool
#  4   Category_C     5 non-null      bool
# dtypes: bool(3), int64(1), object(1)
# memory usage: 227.0+ bytes

# %% [markdown]
# ## 2. Derived Data

# %%
from datetime import datetime

# %%
#Example data
data = {'Name': ['Alice', 'Bob'], 'Date_of_Birth': ['1990-05-14', '1985-08-23']}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name Date_of_Birth
# 0  Alice    1990-05-14
# 1    Bob    1985-08-23

# %%
df.describe()
# Out:
#          Name Date_of_Birth
# count       2             2
# unique      2             2
# top     Alice    1990-05-14
# freq        1             1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           2 non-null      object
#  1   Date_of_Birth  2 non-null      object
# dtypes: object(2)
# memory usage: 164.0+ bytes

# %%
df.shape
# Out:
# (2, 2)

# %%
# Convert Date_of_Birth to datetime
df['Date_of_Birth'] = pd.to_datetime(df['Date_of_Birth'])

# %%
df
# Out:
#     Name Date_of_Birth
# 0  Alice    1990-05-14
# 1    Bob    1985-08-23

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           2 non-null      object
#  1   Date_of_Birth  2 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 164.0+ bytes

# %%
# Calculating Age
current_year = datetime.now().year
df['Age'] = current_year - df['Date_of_Birth'].dt.year

# %%
df['Age']
# Out:
# 0    35
# 1    40
# Name: Age, dtype: int32

# %%
df
# Out:
#     Name Date_of_Birth  Age
# 0  Alice    1990-05-14   35
# 1    Bob    1985-08-23   40

# %%
df.describe()
# Out:
#              Date_of_Birth        Age
# count                    2   2.000000
# mean   1988-01-02 12:00:00  37.500000
# min    1985-08-23 00:00:00  35.000000
# 25%    1986-10-28 06:00:00  36.250000
# 50%    1988-01-02 12:00:00  37.500000
# 75%    1989-03-08 18:00:00  38.750000
# max    1990-05-14 00:00:00  40.000000
# std                    NaN   3.535534

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           2 non-null      object
#  1   Date_of_Birth  2 non-null      datetime64[ns]
#  2   Age            2 non-null      int32
# dtypes: datetime64[ns](1), int32(1), object(1)
# memory usage: 172.0+ bytes

# %% [markdown]
# ## 3. Grouping and Aggregating Data
#
# using Groupby and Pivot_tabel

# %%
# Example data
data = {
    'Category': ['A', 'A', 'B', 'B', 'C'],
    'Value': [10, 20, 10, 30, 40]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#   Category  Value
# 0        A     10
# 1        A     20
# 2        B     10
# 3        B     30
# 4        C     40

# %%
df.describe()
# Out:
#            Value
# count   5.000000
# mean   22.000000
# std    13.038405
# min    10.000000
# 25%    10.000000
# 50%    20.000000
# 75%    30.000000
# max    40.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  5 non-null      object
#  1   Value     5 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 212.0+ bytes

# %%
df.shape
# Out:
# (5, 2)

# %%
# Group by and aggregate
grouped = df.groupby('Category').agg({'Value': ['sum', 'mean']})
print("Grouped Data:")
grouped
# Out:
# Grouped Data:
#          Value
#            sum  mean
# Category
# A           30  15.0
# B           40  20.0
# C           40  40.0

# %%
# Pivot Tabel
pivot = df.pivot_table(index='Category', values='Value', aggfunc=['sum', 'mean'])
print("Pivot Tabel:")
pivot
# Out:
# Pivot Tabel:
#            sum  mean
#          Value Value
# Category
# A           30  15.0
# B           40  20.0
# C           40  40.0

# %%
df
# Out:
#   Category  Value
# 0        A     10
# 1        A     20
# 2        B     10
# 3        B     30
# 4        C     40
