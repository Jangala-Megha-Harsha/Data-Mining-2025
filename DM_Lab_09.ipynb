# %% [markdown]
# <a href="https://colab.research.google.com/github/Jangala-Megha-Harsha/Data-Mining-2025/blob/main/DM_Lab_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab - 09
# 2303A51409

# %% [markdown]
# ## **1. Employee Salary Analysis**
# A company wants to analyze its employees’ salaries to determine increments based on performance. The HR department has collected the following dataset:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    "Employee": ["John", "Sarah", "Mike", "Emma", "Tom"],
    "Department": ["It", "HR", "IT", "Finance", "HR"],
    "Salary": [60000, 50000, 75000, 65000, 48000],
    "Experience (Years)": [5, 3, 7, 4, 2],
    "Performance Rating (Out of 5)": [4.5, 3.8, 4.9, 4.2, 3.5]
}

# %% [markdown]
# Q1 : Create a DataFrame using the given Data

# %%
df = pd.DataFrame(data)
df
# Out:
#   Employee Department  Salary  Experience (Years)  \
# 0     John         It   60000                   5
# 1    Sarah         HR   50000                   3
# 2     Mike         IT   75000                   7
# 3     Emma    Finance   65000                   4
# 4      Tom         HR   48000                   2
#
#    Performance Rating (Out of 5)
# 0                            4.5
# 1                            3.8
# 2                            4.9
# 3                            4.2
# 4                            3.5

# %% [markdown]
# Q2 : Calculate the average salary of employees in each department.

# %%
avg_salary_by_department = df.groupby('Department')['Salary'].mean()
avg_salary_by_department
# Out:
# Department
# Finance    65000.0
# HR         49000.0
# IT         75000.0
# It         60000.0
# Name: Salary, dtype: float64

# %% [markdown]
# Q3 : Filter out employees who have a performance rating above 4.0.

# %%
top_performaers = df[df['Performance Rating (Out of 5)'] > 4.0]
top_performaers
# Out:
#   Employee Department  Salary  Experience (Years)  \
# 0     John         It   60000                   5
# 2     Mike         IT   75000                   7
# 3     Emma    Finance   65000                   4
#
#    Performance Rating (Out of 5)
# 0                            4.5
# 2                            4.9
# 3                            4.2

# %% [markdown]
# Q4 : Add a new column called "Increment", where employees with a rating above 4 get a 10% increment, and others get a 5% increment.

# %%
df['Increment'] = np.where(df['Performance Rating (Out of 5)'] > 4, 0.10, 0.05)
df
# Out:
#   Employee Department  Salary  Experience (Years)  \
# 0     John         It   60000                   5
# 1    Sarah         HR   50000                   3
# 2     Mike         IT   75000                   7
# 3     Emma    Finance   65000                   4
# 4      Tom         HR   48000                   2
#
#    Performance Rating (Out of 5)  Increment
# 0                            4.5       0.10
# 1                            3.8       0.05
# 2                            4.9       0.10
# 3                            4.2       0.10
# 4                            3.5       0.05

# %%
df.columns
# Out:
# Index(['Employee', 'Department', 'Salary', 'Experience (Years)',
#        'Performance Rating (Out of 5)', 'Increment'],
#       dtype='object')

# %% [markdown]
# Q5 : Sort employees in descending order of salary after the increment.

# %%
df['New Salary'] = df['Salary'] + df['Salary'] * df['Increment']
df
# Out:
#   Employee Department  Salary  Experience (Years)  \
# 0     John         It   60000                   5
# 1    Sarah         HR   50000                   3
# 2     Mike         IT   75000                   7
# 3     Emma    Finance   65000                   4
# 4      Tom         HR   48000                   2
#
#    Performance Rating (Out of 5)  Increment  New Salary
# 0                            4.5       0.10     66000.0
# 1                            3.8       0.05     52500.0
# 2                            4.9       0.10     82500.0
# 3                            4.2       0.10     71500.0
# 4                            3.5       0.05     50400.0

# %%
df_sorted = df.sort_values('New Salary', ascending=False)
df_sorted
# Out:
#   Employee Department  Salary  Experience (Years)  \
# 2     Mike         IT   75000                   7
# 3     Emma    Finance   65000                   4
# 0     John         It   60000                   5
# 1    Sarah         HR   50000                   3
# 4      Tom         HR   48000                   2
#
#    Performance Rating (Out of 5)  Increment  New Salary
# 2                            4.9       0.10     82500.0
# 3                            4.2       0.10     71500.0
# 0                            4.5       0.10     66000.0
# 1                            3.8       0.05     52500.0
# 4                            3.5       0.05     50400.0

# %% [markdown]
# ## **2. COVID-19 Cases Analysis**
# A health department is monitoring COVID-19 cases in different cities. They have recorded the following data:

# %%
data_2 = {
    "city": ["New York", "Los Angeles", "Chicago", "Houston", "Miami"],
    "total_cases": [100000, 85000, 65000, 70000, 55000],
    "recovered": [75000, 70000, 50000, 60000, 45000],
    "deaths": [5000, 3500, 2500, 2000, 1500]
}

# %% [markdown]
# Q1 : Create a DataFrame for the given data.

# %%
df2 = pd.DataFrame(data_2)
df2
# Out:
#           city  total_cases  recovered  deaths
# 0     New York       100000      75000    5000
# 1  Los Angeles        85000      70000    3500
# 2      Chicago        65000      50000    2500
# 3      Houston        70000      60000    2000
# 4        Miami        55000      45000    1500

# %% [markdown]
# Q2 : Calculate the recovery rate ((Recovered / Total Cases) * 100) for each city and add it as a new column.

# %%
df2['recovery_rate'] = (df2['recovered'] / df2['total_cases']) * 100
df2
# Out:
#           city  total_cases  recovered  deaths  recovery_rate
# 0     New York       100000      75000    5000      75.000000
# 1  Los Angeles        85000      70000    3500      82.352941
# 2      Chicago        65000      50000    2500      76.923077
# 3      Houston        70000      60000    2000      85.714286
# 4        Miami        55000      45000    1500      81.818182

# %% [markdown]
# Q3 : Identify cities where the death rate ((Deaths / Total Cases) * 100) is higher than 5%.

# %%
df2['death_rate'] = (df2['deaths'] / df2['total_cases']) * 100

high_death_rate_cities = df2[df2['death_rate'] >= 5.0]['city']
high_death_rate_cities
# Out:
# 0    New York
# Name: city, dtype: object

# %% [markdown]
# Q4 : Sort the cities by the highest recovery rate.

# %%
sorted_df2 = df2.sort_values('recovery_rate', ascending=False)
sorted_df2
# Out:
#           city  total_cases  recovered  deaths  recovery_rate  death_rate
# 3      Houston        70000      60000    2000      85.714286    2.857143
# 1  Los Angeles        85000      70000    3500      82.352941    4.117647
# 4        Miami        55000      45000    1500      81.818182    2.727273
# 2      Chicago        65000      50000    2500      76.923077    3.846154
# 0     New York       100000      75000    5000      75.000000    5.000000

# %% [markdown]
# Q5 : Find the total number of cases and deaths across all cities.

# %%
total_cases = df2['total_cases'].sum()
total_deaths = df2['deaths'].sum()

print("Total Cases:", total_cases)
print("Total Deaths:", total_deaths)
# Out:
# Total Cases: 375000
# Total Deaths: 14500

# %% [markdown]
# ## **3. Online Shopping Sales Analysis**
# An e-commerce company wants to analyze its sales data. The dataset contains the following details:

# %%
data3 = {
    "Order ID": [1001, 1002, 1003, 1004, 1005],
    "Customer": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Product": ["Laptop", "Phone", "Tablet", "Laptop", "Phone"],
    "Price": [800, 500, 300, 750, 600],
    "Quantity": [1, 2, 1, 1, 1],
    "Discount (%)": [10, 5, 15, 8, 12]
}

# %%
df3 = pd.DataFrame(data3)
df3
# Out:
#    Order ID Customer Product  Price  Quantity  Discount (%)
# 0      1001    Alice  Laptop    800         1            10
# 1      1002      Bob   Phone    500         2             5
# 2      1003  Charlie  Tablet    300         1            15
# 3      1004    David  Laptop    750         1             8
# 4      1005     Emma   Phone    600         1            12
